# %%
import xarray as xr

# %%
with xr.open_dataset("/mnt/f/HydroResearchData/MeteoData//ecmwf_forecast/71590976ea4f4163acb90dc3f47df67.nc") as f:
    ds = f
ds
# Out:
# <xarray.Dataset> Size: 117MB
# Dimensions:                  (number: 51, forecast_reference_time: 1,
#                               forecast_period: 30, latitude: 42, longitude: 152)
# Coordinates:
#   * number                   (number) int64 408B 0 1 2 3 4 5 ... 46 47 48 49 50
#   * forecast_reference_time  (forecast_reference_time) datetime64[ns] 8B 2024...
#   * forecast_period          (forecast_period) timedelta64[ns] 240B 1 days .....
#   * latitude                 (latitude) float64 336B 82.0 81.0 ... 42.0 41.0
#   * longitude                (longitude) float64 1kB 19.0 20.0 ... 169.0 170.0
#     valid_time               (forecast_period) datetime64[ns] 240B ...
# Data variables:
#     mx2t24                   (number, forecast_reference_time, forecast_period, latitude, longitude) float32 39MB ...
#     mn2t24                   (number, forecast_reference_time, forecast_period, latitude, longitude) float32 39MB ...
# ...

# %%
ds['valid_time'].values
# Out:
# array(['2024-10-02T00:00:00.000000000', '2024-10-03T00:00:00.000000000',
#        '2024-10-04T00:00:00.000000000', '2024-10-05T00:00:00.000000000',
#        '2024-10-06T00:00:00.000000000', '2024-10-07T00:00:00.000000000',
#        '2024-10-08T00:00:00.000000000', '2024-10-09T00:00:00.000000000',
#        '2024-10-10T00:00:00.000000000', '2024-10-11T00:00:00.000000000',
#        '2024-10-12T00:00:00.000000000', '2024-10-13T00:00:00.000000000',
#        '2024-10-14T00:00:00.000000000', '2024-10-15T00:00:00.000000000',
#        '2024-10-16T00:00:00.000000000', '2024-10-17T00:00:00.000000000',
#        '2024-10-18T00:00:00.000000000', '2024-10-19T00:00:00.000000000',
#        '2024-10-20T00:00:00.000000000', '2024-10-21T00:00:00.000000000',
#        '2024-10-22T00:00:00.000000000', '2024-10-23T00:00:00.000000000',
#        '2024-10-24T00:00:00.000000000', '2024-10-25T00:00:00.000000000',
#        '2024-10-26T00:00:00.000000000', '2024-10-27T00:00:00.000000000',
# ...
